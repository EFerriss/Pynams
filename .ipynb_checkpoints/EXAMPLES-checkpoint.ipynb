# %% [markdown]
# # Pynams: A Python Package for Nominally Anhdydrous Minerals
# An example of processing FTIR spectra with pynams from https://github.com/EFerriss/pynams
#
# ## First get pynams and basic python scientific and plotting packages
# pynams is written in Python 2.7 and requires the [lmfit](https://pypi.python.org/pypi/lmfit/)
# and [uncertainties](https://pythonhosted.org/uncertainties/) packages. For those new to python, I recommend downloading [anaconda](https://www.continuum.io/downloads).

# %%
# %matplotlib inline
from pynams import pynams
import numpy as np

# %% [markdown]
# ## Create a spectrum object
# The core structure you need to understand to handle FTIR spectra with pynams is a class called Spectrum. Each of your FTIR spectra will have to be created as an object, and pynams.Spectrum is the class, or template, for making these objects. Each Spectrum object then by default has attributes like thickness (thick_microns) and the ability to create and save baselines.
#
# **Note:** Each FTIR spectrum **requires** information about the sample thickness, a short descriptive name (fname), and the location of the file containing the data. Currently only .CSV files are supported. The spectrum's fname should be the same as the filename without the extension. So if your spectrum is saved as pynamsDemo.CSV, the spectrum's fname should be the string 'pynamsDemo'.
#
# Here in the first line I create a particular spectrum ("instantiating the class Spectrum" in object-oriented parlance), which I call spectrum, and I specify the fname and thickness while creating it.

# %%
spectrum = pynams.Spectrum(fname = 'pynamsDemo', thick_microns = np.mean([885., 867., 873., 878., 879.]))

# %% [markdown]
# This spectrum needs data from the file pynamsDemo.CSV. If that file is in the same folder as your python script, you don't need to specify the folder.

# %%
## Here I get my test data from the web and save it locally to a specific folder.
# This usually does not require specifying the folder location explicitly, but it's best to do it anyway
FTIR_file_location = 'C:\\Users\\Ferriss\\Documents\\FTIR\\'

import requests
r = requests.get('https://raw.githubusercontent.com/EFerriss/HydrogenCpx/master/FTIR_CSV_FILES/P_0_unpol.CSV')
f = open(''.join((FTIR_file_location, spectrum.fname)), 'w')
f.write(r.content)

### If you have the FTIR file on your computer

## Option 1: Specify the spectrum's filename explicitly
# spectrum.filename = FTIR_file_location + spectrum.fname + '.CSV'

## Option 2: Use the pynams built-in function make_filenames. This option is handy when you have more than one spectrum.
# pynams.make_filenames(folder=FTIR_file_location, file_ending='.CSV')

# %% [markdown]
# ## Plotting spectra
# Now I can look at the spectrum by calling the method plot_spectrum. This function returns handles for the figure and axis, which you can then save or adjust as with any other figure generated using matplotlib.

# %%
print spectrum.filename
#fig, ax = spectrum.plot_spectrum()
#fig.set_size_inches(4, 4)
# Out:
# C:\Users\Ferriss\Documents\FTIR\pynamsDemo.CSV

# %% [markdown]
# To show another spectrum on the same plot, do the same thing but

# %%
# Making second spectrum called spectrum2
spectrum2 = pynams.Spectrum(fname = 'pynamsDemo2', thick_microns = np.mean([885., 867., 873., 878., 879.]))
r = requests.get('https://raw.githubusercontent.com/EFerriss/HydrogenCpx/master/FTIR_CSV_FILES/P_6_unpol.CSV')
f = open('pynamsDemo2.CSV', 'w')
f.write(r.content)

pynams.make_filenames(folder='C:hello')
print spectrum2.filename

#spectrum.plot_spectrum()
#spectrum2.plot_spectrum(figaxis=ax)
# Out:
# pynamsDemo2.CSV

# %% [markdown]
# ## Making baselines
# The default is a line between wavenumbers 3200 and 3700 cm-1, but you can also make quadratic baselines and change the wavenumber range. Here are three examples:

# %%
fig, ax = spectrum.plot_showbaseline()
# Out:
# Making baseline...

# %%
spectrum.base_low_wn = 3350
baseline = spectrum.make_baseline(line_order=2, shiftline=-0.2, show_plot=True)

# %%
baseline = spectrum.make_baseline(line_order=2, shiftline=0.3, show_plot=False)
fig, ax = spectrum.plot_showbaseline()

# %% [markdown]
# ## Subtracting the baseline

# %%
fig, ax = spectrum.plot_subtractbaseline()

# %% [markdown]
# ## Estimating peak area and water concentration
# Right now only the mineral-specific area calibrations from Bell et al. 1995 for clinopyroxene (mineral_name='cpx'; the default because that's what I, Elizabeth Ferriss, happen to work on) and Bell&Rossman 2003 for olivine (mineral_name='olivine') are included, but other calibrations (Paterson, wavenumber-specific, other minerals) can be added either by me upon request, or, because the code is open source, by you, dear reader.
#
# For this simple case, the water concentration returned is just the area between the curve and baseline multiplied by the integral specific absorption coefficient, and the error is propogated only from the error on that absorption coefficient. Ideally one would add up these areas from spectra polarized in three orthogonal directions (Libowitzky&Rossman, 1996).

# %%
area, water = spectrum.water(mineral_name='cpx', show_plot=True)
# Out:
# Using previously fit baseline. Use make_baseline to change it.
# pynamsDemo
# area: 383.6 /cm^2
# water: 54.1+/-2.4 ppm H2O; *3 = 162.3+/-7.3 ppm H2O
