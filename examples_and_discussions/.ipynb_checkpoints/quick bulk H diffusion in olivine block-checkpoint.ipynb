# %% [markdown]
# # Roughly how far will H diffuse in an olivine block?
#
# ## Examples from reading Demouchy et al. 2016 experiments at 3 GPa
#
# First I import the code I need, all of which is available here on github. Let me know if you try installing it and have trouble. All of the actual code is in a series of documents called modules, which are grouped together into a package called pynams.
#
# The modules I am using for this example are
# * pynams - handles basic things like the dimensions of samples, profiles, and groups of 3 orthogonal profiles, which I call 'whole-blocks'
# * diffusion - contains code for modeling diffusion curves in 1D and 3D
# * diffusivity_library - contains a library of previous diffusivity measurements and ways to handle them
#
# Any section in this document with 'In [any number]:' to the left is code I am writing. So let's import some modules.

# %%
from pynams import pynams, diffusion
from pynams import diffusivity_library as dlib # shortened name so I don't have to type it out every time
import numpy as np # This package let's me do a little more math than I could otherwise

# %% [markdown]
# This next line just makes my plots show up correctly

# %%
# %matplotlib inline

# %% [markdown]
# ## Samples
#
#
# Here are the samples and dimensions (in microns) of the 6 olivine blocks in Table 1 of Demouchy et al. 2016. twoA, twoB, and twoC refer to the lengths of the dimensions parallel to [100], [010], and [001]. I use [bracketed lists] so I can accommodate multiple thickness measurements.

# %%
SD1 = pynams.Sample(twoA_list=[1060.], twoB_list=[2060.], twoC_list=[1740.])
SD2 = pynams.Sample(twoA_list=[1600.], twoB_list=[2080.], twoC_list=[1770.])
SD3 = pynams.Sample(twoA_list=[1600.], twoB_list=[2020.], twoC_list=[1730.])
SD5 = pynams.Sample(twoA_list=[1010.], twoB_list=[1090.], twoC_list=[2090.])
SD6 = pynams.Sample(twoA_list=[1040.], twoB_list=[1180.], twoC_list=[2040.])
SD7 = pynams.Sample(twoA_list=[1710.], twoB_list=[2040.], twoC_list=[1040.])

# %% [markdown]
# I will never have to type or look up those numbers in here again. If I want them, I just ask for them. The [0] in this example tells it to grab the first value, not the full list.

# %%
volumeSD2 = SD2.twoA_list[0] * SD2.twoB_list[0] * SD3.twoC_list[0]
print 'The volume of sample block SD2 is', volumeSD2 / (1e9), 'mm^3'
# Out:
# The volume of sample block SD2 is 5.75744 mm^3

# %% [markdown]
# ## fast_vs_slow() bulk H diffusion mechanisms
#
# The pynams function fast_vs_slow provides a quick general idea of the simultaneous progress of both the proton-polaron (PP) and proton-vacancy (PV) bulk H diffusion mechanisms in olivine. It assumes no interaction at all between the two mechanisms, which is maybe wrong (Thoraval & Demouchy 2014), but it's fast and gives a nice general idea about what's happening. The plot also uses the same normalized scale for both mechanisms, but note the final area for PV will be much higher than that for PP.
#
# The function fast_vs_slow requires the temperature in celsius, the sample (which includes all 3 dimensions, as above) and the time in minutes.
#
# It returns the figure (which is what you can resize and/or save) and the 3 axes of the different subplotss (which is what you use if you want to plot more stuff).
#
# Here's the first sample from Demouchy et al.'s table:
#
# ### SD1 at 1093 C

# %%
figure, axes = dlib.fast_vs_slow(celsius=1093., sample=SD1, minutes=60.*5, printout=False)

# %% [markdown]
# The green is the slower pv mechanism.
#
# All of these profiles are non-path-integrated, meaning this is what you would expect to see if you could cut the sample open and take a perfect set of measurements through the center exactly parallel to each axis.
#
# If you want to see when the pp mechanism saturates, shorten the time.

# %%
figure, axes = dlib.fast_vs_slow(celsius=1093., sample=SD1, minutes=5., printout=False)

# %% [markdown]
# Hydration looks the same just flipped vertically. Note that this is just to compare relative progress. In real olivine, the pp mechanism (black) saturates at some lower-than-true-solubility, and as a result the pv mechanism (thick green) is squished upward.
#
# ## Calculating the diffusivities
#
# ### fast_vs_slow(printout=True)
#
# In the next example for Demouchy et al's 2nd sample, I'm also having it print out the actual diffusitivies in order || a, || b, and || c.
#
# ### SD2 at 905 C (Fig. 9)

# %%
figure, axes = dlib.fast_vs_slow(celsius=905., sample=SD2, minutes=60., printout=True)
# Out:
# slower proton-vacancy pv mechanism diffusivities
# log10 D at  905.0 C:  -13.9  in m2/s
# log10 D at  905.0 C:  -14.1  in m2/s
# log10 D at  905.0 C:  -12.8  in m2/s
#
# faster proton-polaron pp mechanism diffusivites
# log10 D at  905.0 C:  -10.1  in m2/s
# log10 D at  905.0 C:  -11.5  in m2/s
# log10 D at  905.0 C:  -11.4  in m2/s

# %% [markdown]
# ### Compare SD2 to my San Carlos hydration experiment at 800C
#
# Demouchy et al.'s SD2-274 experiment is very similar to my San Carlos olivine sample SC1-2, which I hydrated at 800C for 17.5 hours, and which also went a little faster than I was expecting (it's very homogeneous; I don't see much change at the edge at all). That sample, shown below, has multiple entries in the lists because I measured the thickness multiple times.

# %%
SC1_2 = pynams.Sample(twoA_list=[2310., 2292., 2319., 2309., 2318.],
                      twoB_list=[1963., 1987., 1976., 1987., 1980.],
                      twoC_list=[2858., 2864., 2858., 2863., 2864.])
figure, axes = dlib.fast_vs_slow(celsius=800., sample=SC1_2, minutes=60.*17.5, printout=False)

# %% [markdown]
# My San Carlos was actually either a little bit faster than that or else my thickness measurements are too large, because the profiles look homogeneous, not curving like these black lines. The point is that I would expect Demouchy et al.'s SD2 to have a similar fairly flat profile.
#
# ### whatIsD()
# If you just want the diffusivities, find the appropriate Diffusivity object (where the activation energies, etc. are stored; use tab complete after dlib to see options I already have input) and then use the function whatIsD() with the temperature input. The output is an array of log10 of the diffusivities || [100], || [010], || [001], and unoriented in m2/s.
#
# Here's an example for the fast proton-polaron mechanism from Kohlstedt & Mackwell 1998:

# %%
dlib.KM98_fast.whatIsD(celsius=900.)
# Out:
# [-10.131632934635144, -11.552727607249828, -11.449814459014474, None]

# %% [markdown]
# Compare that with the result for Padron-Navarta et al. 2014's site-specific H diffusion results for the Si-vacancy-related [Si] mechanism:

# %%
dlib.pnav_Si.whatIsD(celsius=900.)
# Out:
# [None, None, None, -17.300818270360359]

# %% [markdown]
# The Kohlstedt & Mackwell 1998 PP mechanism (KM98_fast) has 3 diffusivities in 3 directions, whereas the Padron-Navarta et al. were not using oriented samples. You can store the output array in a variable and then call the numbers up later (start with 0 for the first one).
#
# Here I'm calculating and then printing out only the final value (index 3) for Padron-Navarta et al.'s site-specific Mg-vacancy-related [Mg] H diffusion mechanism:

# %%
D = dlib.pnav_Mg.whatIsD(celsius=900.)
print D[3]
# Out:
# -13.5058530772

# %% [markdown]
# And for the slower PV mechanism diffusivities used to calculate the think green lines in all of these fast_vs_slow plots:

# %%
D = dlib.KM98_slow.whatIsD(celsius=900.)
print D[0:3]
# Out:
# [-13.996778169870476, -14.172291818084735, -12.887544170426397]

# %% [markdown]
# ## Great. Back to Demouchy et al. 2016
#
# ### SD6 at 900C (Figs. 4 and 7)
#
# The other Demouchy et al. sample at 900C I would expect has progressed a little bit further but not much. Demouchy et al. see more movement || a (their Fig. 4) that I would expect based on the lower pressure experiments used to calculate these curves.

# %%
figure, axes = dlib.fast_vs_slow(celsius=900., sample=SD6, minutes=60.*10., printout=False) # Real experiment in first plot

# %%
figure, axes = dlib.fast_vs_slow(celsius=900., sample=SD6, minutes=60.*1., printout=False) # When pp saturates in second plot

# %% [markdown]
# ### SD3 (Fig. 8) and SD5 at 1200 C
# Both Demouchy et al. samples at 1200C should be fully saturated, and indeed they were in the experiments.
#
# Sometimes the error function that I'm using to calculate the diffusion profiles does crazy things at the very end. The upward curvature is a bug in my code, not a real profile, and should be interpreted as the system having reaching equilibrium.

# %%
figure, axesSD3 = dlib.fast_vs_slow(celsius=1200., sample=SD3, minutes=60.*10., printout=False)
figure, axesSD5 = dlib.fast_vs_slow(celsius=1200., sample=SD5, minutes=60.*5., printout=False)
title = axesSD3[1].set_title('SD3')
title = axesSD5[1].set_title('SD5')

# %% [markdown]
# ### SD7 1000C

# %%
figure, axes = dlib.fast_vs_slow(celsius=1000., sample=SD7, minutes=60.*5., printout=False)

# %% [markdown]
# They don't show the final measured profiles for SD7, only the diffusivities reported in Table 4, so let's plot those up.
#
# ### Plotting diffusion profiles with diffusion3Dnpi()
#
# The 'npi' at the end of 'diffusion3Dnpi'stands for 'non-path-integrated', meaning we're assuming there aren't any whole-block effects with the absorbance signal getting integrated. By default, this function plots up the diffusion profiles you would see if you cut the sample and returns, in order:
# * The figure handle, as in the above
# * A list of the 3 axes, one for each subplot
# * v, a 3-D matrix containing the concentrations distributed throughout the entire block
# * All of the x-axis data used to make the plot
# * All of the y-axis data in the plot

# %%
# Here I set up the variables that will go into the function
sample = SD7 # If I decide to do the same thing with another sample, I only have to change one thing
a = sample.twoA_list[0]
b = sample.twoB_list[0]
c = sample.twoC_list[0]
time_seconds = 5. * 3600.
reported_diffusivities_in_each_direction_in_m2s = [2e-12, 2e-12, 2e-12]
# I imported numpy at the beginning so I could do this nex step
# It's good practice to keep all of your imports at the top so a new person can see everything they will need to run the code
log10D = np.log10(reported_diffusivities_in_each_direction_in_m2s)
print 'The log10 diffusivities in m2/s are', log10D
# Out:
# The log10 diffusivities in m2/s are [-11.69897 -11.69897 -11.69897]

# %%
figure, axes, v, x, y = diffusion.diffusion3Dnpi(lengths_microns=[a, b, c],
                                              log10Ds_m2s=log10D, 
#                                              time_seconds=60., 
#                                              initial=1., final=0.,
#                                              plot3=True, centered=False)

# %%
#figure, axes, v, x, y = diffusion.diffusion3Dnpi(lengths_microns=[a, b, c],
#                                              log10Ds_m2s=[-12]*3, 
#                                              time_seconds=60., 
#                                              initial=1., final=0.,
#                                              plot3=True, centered=False)
#
# Out:
# [-11.69897 -11.69897 -11.69897]

# %% [markdown]
# # Results from Demouchy et al. 2016
#
# Everything I did above was to get a sense for what I would expect based on previous work. Now let's dig into the new work.
#
# Unfortunately, the raw spectra are not available, so we'll focus only on the reported diffusivities, specifically those with E || [100], because those are the profiles most directly comparable to my work.
